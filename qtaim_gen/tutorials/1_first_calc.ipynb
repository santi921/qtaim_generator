# %% [markdown]
# # First calculation
#
# Here we will outline the simplest possible full analysis via generator. This analysis should include the following routines:
# 1) QTAIM - the original QTAIM analysis including critical point data, and graphs
# 2) Charges - partial charges, you can set the number of calcs with full_set. Baseline includes hirshfeld, adch, cm5, and becke
# 3) Bonding - Fuzzy, IBSI, Laplacian bonding schemes
# 4) Fuzzy - several fuzzy analysis routines
# 5) Other - mainly geometric information but a whole suite of features Multiwfn computes
#
#
# NB: this method below looks for wfn or gbw files. If there is only a gbw file, it first converts via orca6_2mkl. wfn files work directly.

# %%
# main module for GBW analysis
import os
import resource
import logging
from qtaim_gen.source.core.omol import gbw_analysis


# options
restart = False
multiwfn_cmd = (
    "/home/santiagovargas/dev/Multiwfn_3.8_dev_bin_Linux_noGUI/Multiwfn_noGUI"
)
orca6_2mkl = "/home/santiagovargas/orca_6_0_0/orca_2mkl"
full_set = 1  # level of analysis: 0 (minimal), 1 (standard), 2 (full)
debug = False
clean = True
overwrite = True
run_root = "/trial_run/1/"

resource.setrlimit(
    resource.RLIMIT_STACK, (resource.RLIM_INFINITY, resource.RLIM_INFINITY)
)

logging.basicConfig(
    filename=os.path.join(run_root, "gbw_analysis.log"),
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

gbw_analysis(
    folder=run_root,
    orca_2mkl_cmd=orca6_2mkl,
    multiwfn_cmd=multiwfn_cmd,
    parse_only=True,
    separate=True,  # default to true b/c this is how restarts work best
    overwrite=overwrite,
    orca_6=True,
    clean=clean,
    n_threads=4,
    full_set=full_set,
    restart=restart,
    debug=debug,
    logger=logging.getLogger("gbw_analysis"),
    preprocess_compressed=False,
)  # works!
# Out:
# INFO:gbw_analysis:Starting gbw_analysis in folder: /home/santiagovargas/dev/qtaim_generator/qtaim_gen/tutorials/trial_run/1/
# INFO:gbw_analysis:Restarting from last step in timings.json
# INFO:gbw_analysis:... Cleaning up
# INFO:gbw_analysis:Cleaning up jobs in folder: /home/santiagovargas/dev/qtaim_generator/qtaim_gen/tutorials/trial_run/1/
# INFO:gbw_analysis:gbw_analysis completed in folder: /home/santiagovargas/dev/qtaim_generator/qtaim_gen/tutorials/trial_run/1/
# INFO:gbw_analysis:Validation status: False
# ... Parsing multiwfn output
# Using input file "input.in" for validation.
# n_atoms: 21, spin: 1, charge: 0
# spin tf:  True  spin:  1 <class 'str'>
# Missing expected spin key 'mbis_fuzzy_spin' in timing json.

# %%
# Now lets check some of the outputs!
import json

timings_file = "./trial_run/1/timings.json"
qtaim_output_file = "./trial_run/1/qtaim.json"
other_output_file = "./trial_run/1/other.json"
bonds_output_file = "./trial_run/1/bond.json"
charges_output_file = "./trial_run/1/charge.json"

with open(timings_file, "r") as f:
    timings_data = json.load(f)

with open(qtaim_output_file, "r") as f:
    qtaim_data = json.load(f)

with open(other_output_file, "r") as f:
    other_data = json.load(f)

with open(bonds_output_file, "r") as f:
    bonds_data = json.load(f)

with open(charges_output_file, "r") as f:
    charges_data = json.load(f)

# %%
# a simple log of timing info for each routine
print("Timings Data:")
print(json.dumps(timings_data, indent=4))
# Out:
# Timings Data:
# {
#     "convert": 0.07398176193237305,
#     "fuzzy_full": 0.0009639263153076172,
#     "charge_separate": 0.0006101131439208984,
#     "bond_separate": 0.0005068778991699219,
#     "qtaim": 0.4074122905731201,
#     "other": 3.039522409439087,
#     "hirshfeld": 0.6990456581115723,
#     "adch": 0.7080643177032471,
#     "cm5": 0.6913502216339111,
#     "becke": 0.7230823040008545,
#     "vdd": 0.0009725093841552734,
#     "mbis": 0.0006077289581298828,
#     "chelpg": 0.0005826950073242188,
#     "bader": 0.0005042552947998047,
#     "fuzzy_bond": 0.21775150299072266,
#     "ibsi_bond": 0.0006310939788818359,
#     "laplacian_bond": 0.000579833984375,
#     "becke_fuzzy_density": 0.987417459487915,
#     "hirsh_fuzzy_density": 1.5447685718536377,
#     "elf_fuzzy": 0.0008606910705566406,
#     "mbis_fuzzy_density": 0.0009455680847167969,
#     "laplacian_rho_fuzzy": 0.0006346702575683594,
#     "grad_norm_rho_fuzzy": 0.0005300045013427734
# }

# %%
print("QTAIM Data:")
print(json.dumps(qtaim_data, indent=4))
# Out:
# QTAIM Data:
# {
#     "0": {
#         "cp_num": 18,
#         "element": "C",
#         "number": "1",
#         "pos_ang": [
#             0.08700009243,
#             1.547801221742,
#             -0.210600250281
#         ],
#         "density_all": 112.2229336,
#         "density_alpha": 56.11146679,
#         "density_beta": 56.11146679,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.701178171,
#         "Hamiltonian_K": 64619.03995,
#         "energy_density": -64619.03995,
#         "lap_e_density": -258453.3551,
#         "e_loc_func": 0.9999994217,
#         "lol": 0.9992400882,
#         "ave_loc_ion_E": 9.563375614,
#         "delta_g_promolecular": 0.04005368858,
#         "delta_g_hirsh": 0.04907221414,
#         "esp_nuc": 2553441.381,
#         "esp_e": -26.72226376,
#         "esp_total": 2553414.659,
#         "grad_norm": 1.469657023e-11,
#         "lap_norm": -258453.3551,
#         "eig_hess": -258453.35508999997,
#         "det_hessian": -639414909600000.0,
#         "ellip_e_dens": 2e-06,
#         "eta": -1.000002
#     },
#     "1": {
#         "cp_num": 16,
#         "element": "C",
#         "number": "2",
#         "pos_ang": [
#             0.034699818621,
#             0.046698376122,
#             -0.035199539787
#         ],
#         "density_all": 112.3419115,
#         "density_alpha": 56.17095576,
#         "density_beta": 56.17095576,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.658883903,
#         "Hamiltonian_K": 64703.22402,
#         "energy_density": -64703.22402,
#         "lap_e_density": -258790.2605,
#         "e_loc_func": 0.9999994322,
#         "lol": 0.9992470513,
#         "ave_loc_ion_E": 9.57071666,
#         "delta_g_promolecular": 0.04333062001,
#         "delta_g_hirsh": 0.05220199839,
#         "esp_nuc": 1870124.775,
#         "esp_e": -30.59942098,
#         "esp_total": 1870094.175,
#         "grad_norm": 1.285274398e-13,
#         "lap_norm": -258790.2605,
#         "eig_hess": -258790.26053,
#         "det_hessian": -641918687800000.0,
#         "ellip_e_dens": 3e-06,
#         "eta": -1.000004
#     },
#     "2": {
#         "cp_num": 13,
#         "element": "C",
#         "number": "3",
#         "pos_ang": [
#             0.561100023097,
#             -0.936400210737,
#             -1.114300043225
#         ],
#         "density_all": 112.2764093,
#         "density_alpha": 56.13820467,
#         "density_beta": 56.13820467,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.702088453,
#         "Hamiltonian_K": 64656.86467,
#         "energy_density": -64656.86467,
#         "lap_e_density": -258604.6503,
#         "e_loc_func": 0.9999994224,
#         "lol": 0.9992405697,
#         "ave_loc_ion_E": 9.556166153,
#         "delta_g_promolecular": 0.03766962801,
#         "delta_g_hirsh": 0.04696224802,
#         "esp_nuc": 14992683.95,
#         "esp_e": -28.03286854,
#         "esp_total": 14992655.92,
#         "grad_norm": 4.803655335e-12,
#         "lap_norm": -258604.6503,
#         "eig_hess": -258604.65032000002,
#         "det_hessian": -640538482500000.0,
#         "ellip_e_dens": 3e-06,
#         "eta": -1.000003
#     },
#     "3": {
#         "cp_num": 4,
#         "element": "C",
#         "number": "4",
#         "pos_ang": [
#             0.049500101883,
#             -1.84169913459,
#             0.01329974306
#         ],
#         "density_all": 112.34912,
#         "density_alpha": 56.17455998,
#         "density_beta": 56.17455998,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.667308736,
#         "Hamiltonian_K": 64707.36935,
#         "energy_density": -64707.36935,
#         "lap_e_density": -258806.8082,
#         "e_loc_func": 0.9999994306,
#         "lol": 0.9992460117,
#         "ave_loc_ion_E": 9.559506182,
#         "delta_g_promolecular": 0.04446036935,
#         "delta_g_hirsh": 0.0536029473,
#         "esp_nuc": 3461507.511,
#         "esp_e": -29.30034147,
#         "esp_total": 3461478.21,
#         "grad_norm": 1.701681364e-12,
#         "lap_norm": -258806.8082,
#         "eig_hess": -258806.80816000002,
#         "det_hessian": -642041832900000.0,
#         "ellip_e_dens": 1e-06,
#         "eta": -1.000003
#     },
#     "4": {
#         "cp_num": 8,
#         "element": "C",
#         "number": "5",
#         "pos_ang": [
#             0.676099707335,
#             -0.868099993981,
#             1.077499571794
#         ],
#         "density_all": 112.3420512,
#         "density_alpha": 56.17102562,
#         "density_beta": 56.17102562,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.65117172,
#         "Hamiltonian_K": 64701.9657,
#         "energy_density": -64701.9657,
#         "lap_e_density": -258785.2581,
#         "e_loc_func": 0.9999994338,
#         "lol": 0.9992480782,
#         "ave_loc_ion_E": 9.561535735,
#         "delta_g_promolecular": 0.04134071084,
#         "delta_g_hirsh": 0.05019282387,
#         "esp_nuc": 6040682.469,
#         "esp_e": -29.95836133,
#         "esp_total": 6040652.511,
#         "grad_norm": 9.017618491e-12,
#         "lap_norm": -258785.2581,
#         "eig_hess": -258785.25811000002,
#         "det_hessian": -641881463700000.0,
#         "ellip_e_dens": 3e-06,
#         "eta": -1.000004
#     },
#     "5": {
#         "cp_num": 6,
#         "element": "C",
#         "number": "6",
#         "pos_ang": [
#             -0.213002700888,
#             -0.926299275952,
#             2.315799983516
#         ],
#         "density_all": 112.2261554,
#         "density_alpha": 56.11307771,
#         "density_beta": 56.11307771,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.812190089,
#         "Hamiltonian_K": 64623.37433,
#         "energy_density": -64623.37433,
#         "lap_e_density": -258470.2486,
#         "e_loc_func": 0.999999399,
#         "lol": 0.9992253399,
#         "ave_loc_ion_E": 9.563563459,
#         "delta_g_promolecular": 0.04762969567,
#         "delta_g_hirsh": 0.05779699954,
#         "esp_nuc": 1135960.517,
#         "esp_e": -29.07793461,
#         "esp_total": 1135931.439,
#         "grad_norm": 1.055217994e-11,
#         "lap_norm": -258470.2486,
#         "eig_hess": -258470.24858,
#         "det_hessian": -639540301400000.0,
#         "ellip_e_dens": 8e-06,
#         "eta": -1.000019
#     },
#     "6": {
#         "cp_num": 12,
#         "element": "C",
#         "number": "7",
#         "pos_ang": [
#             -1.195599671547,
#             0.190298218769,
#             2.579399369388
#         ],
#         "density_all": 112.2180095,
#         "density_alpha": 56.10900475,
#         "density_beta": 56.10900475,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.766258824,
#         "Hamiltonian_K": 64616.79735,
#         "energy_density": -64616.79735,
#         "lap_e_density": -258444.1244,
#         "e_loc_func": 0.9999994083,
#         "lol": 0.9992313641,
#         "ave_loc_ion_E": 9.567902573,
#         "delta_g_promolecular": 0.0466949073,
#         "delta_g_hirsh": 0.05645378427,
#         "esp_nuc": 1651281.172,
#         "esp_e": -27.5764708,
#         "esp_total": 1651253.595,
#         "grad_norm": 1.34787771e-11,
#         "lap_norm": -258444.1244,
#         "eig_hess": -258444.12435999996,
#         "det_hessian": -639346401400000.0,
#         "ellip_e_dens": 9e-06,
#         "eta": -1.000013
#     },
#     "7": {
#         "cp_num": 5,
#         "element": "C",
#         "number": "8",
#         "pos_ang": [
#             -1.584098288232,
#             -0.953299183471,
#             1.671902054867
#         ],
#         "density_all": 112.2262142,
#         "density_alpha": 56.11310712,
#         "density_beta": 56.11310712,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.812150466,
#         "Hamiltonian_K": 64623.41398,
#         "energy_density": -64623.41398,
#         "lap_e_density": -258470.4073,
#         "e_loc_func": 0.999999399,
#         "lol": 0.9992253459,
#         "ave_loc_ion_E": 9.563558754,
#         "delta_g_promolecular": 0.04762094493,
#         "delta_g_hirsh": 0.05778655773,
#         "esp_nuc": 1134945.466,
#         "esp_e": -29.07779166,
#         "esp_total": 1134916.388,
#         "grad_norm": 2.179636402e-11,
#         "lap_norm": -258470.4073,
#         "eig_hess": -258470.40731,
#         "det_hessian": -639541479700000.0,
#         "ellip_e_dens": 8e-06,
#         "eta": -1.000019
#     },
#     "8": {
#         "cp_num": 7,
#         "element": "C",
#         "number": "9",
#         "pos_ang": [
#             -1.200699485549,
#             -0.905199979438,
#             0.196099950037
#         ],
#         "density_all": 112.3419621,
#         "density_alpha": 56.17098106,
#         "density_beta": 56.17098106,
#         "spin_density": 0.0,
#         "Lagrangian_K": 5.651149701,
#         "Hamiltonian_K": 64701.90712,
#         "energy_density": -64701.90712,
#         "lap_e_density": -258785.0239,
#         "e_loc_func": 0.9999994338,
#         "lol": 0.9992480802,
#         "ave_loc_ion_E": 9.561539892,
#         "delta_g_promolecular": 0.04134334448,
#         "delta_g_hirsh": 0.05019434599,
#         "esp_nuc": 6061408.123,
#         "esp_e": -29.95839427,
#         "esp_total": 6061378.165,
#         "grad_norm": 1.593847484e-11,
#         "lap_norm": -258785.0239,
#         "eig_hess": -258785.02386999998,
#         "det_hessian": -641879720700000.0,
#         "ellip_e_dens": 3e-06,
#         "eta": -1.000004
#     },
#     "9": {
#         "cp_num": 21,
#         "element": "H",
#         "number": "10",
#         "pos_ang": [
#             1.097734869506,
#             1.863390473033,
#             -0.348034031995
#         ],
#         "density_all": 0.3869053412,
#         "density_alpha": 0.1934526706,
#         "density_beta": 0.1934526706,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.008119399515,
#         "Hamiltonian_K": 3.141604623,
#         "energy_density": -3.141604623,
#         "lap_e_density": -12.53394089,
#         "e_loc_func": 0.9998100898,
#         "lol": 0.9864217617,
#         "ave_loc_ion_E": 0.4053570654,
#         "delta_g_promolecular": 0.1154865487,
#         "delta_g_hirsh": 0.2261717,
#         "esp_nuc": 30.87830165,
#         "esp_e": -13.45274212,
#         "esp_total": 17.42555953,
#         "grad_norm": 9.645646901e-16,
#         "lap_norm": -12.53394089,
#         "eig_hess": -12.533940894,
#         "det_hessian": -72.48596179,
#         "ellip_e_dens": 0.000159,
#         "eta": -1.146054
#     },
#     "10": {
#         "cp_num": 20,
#         "element": "H",
#         "number": "11",
#         "pos_ang": [
#             -0.45727681568,
#             1.831152281249,
#             -1.084487531372
#         ],
#         "density_all": 0.3869013543,
#         "density_alpha": 0.1934506772,
#         "density_beta": 0.1934506772,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.008117902323,
#         "Hamiltonian_K": 3.141724083,
#         "energy_density": -3.141724083,
#         "lap_e_density": -12.53442472,
#         "e_loc_func": 0.9998101533,
#         "lol": 0.9864240015,
#         "ave_loc_ion_E": 0.4053258647,
#         "delta_g_promolecular": 0.1154613027,
#         "delta_g_hirsh": 0.2261146688,
#         "esp_nuc": 30.88012784,
#         "esp_e": -13.45162676,
#         "esp_total": 17.42850109,
#         "grad_norm": 2.474252217e-16,
#         "lap_norm": -12.53442472,
#         "eig_hess": -12.534424721,
#         "det_hessian": -72.49452041,
#         "ellip_e_dens": 0.000159,
#         "eta": -1.146025
#     },
#     "11": {
#         "cp_num": 19,
#         "element": "H",
#         "number": "12",
#         "pos_ang": [
#             -0.311739153073,
#             2.097773782521,
#             0.607063037642
#         ],
#         "density_all": 0.3900321489,
#         "density_alpha": 0.1950160744,
#         "density_beta": 0.1950160744,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.008552416583,
#         "Hamiltonian_K": 3.163997652,
#         "energy_density": -3.163997652,
#         "lap_e_density": -12.62178094,
#         "e_loc_func": 0.9997949003,
#         "lol": 0.9858957314,
#         "ave_loc_ion_E": 0.4078395178,
#         "delta_g_promolecular": 0.1175056534,
#         "delta_g_hirsh": 0.231549188,
#         "esp_nuc": 31.45705069,
#         "esp_e": -14.08387215,
#         "esp_total": 17.37317854,
#         "grad_norm": 3.26667572e-16,
#         "lap_norm": -12.62178094,
#         "eig_hess": -12.621780939999999,
#         "det_hessian": -74.01642839,
#         "ellip_e_dens": 0.000156,
#         "eta": -1.146789
#     },
#     "12": {
#         "cp_num": 14,
#         "element": "H",
#         "number": "13",
#         "pos_ang": [
#             0.024081227375,
#             -0.957277871933,
#             -2.035349398276
#         ],
#         "density_all": 0.391243693,
#         "density_alpha": 0.1956218465,
#         "density_beta": 0.1956218465,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.008123253979,
#         "Hamiltonian_K": 3.18482976,
#         "energy_density": -3.18482976,
#         "lap_e_density": -12.70682602,
#         "e_loc_func": 0.9998168442,
#         "lol": 0.9866621954,
#         "ave_loc_ion_E": 0.3996340054,
#         "delta_g_promolecular": 0.1151696261,
#         "delta_g_hirsh": 0.2276913961,
#         "esp_nuc": 31.59283421,
#         "esp_e": -14.08087004,
#         "esp_total": 17.51196417,
#         "grad_norm": 5.305068591e-16,
#         "lap_norm": -12.70682602,
#         "eig_hess": -12.706826022,
#         "det_hessian": -75.53497428,
#         "ellip_e_dens": 0.001021,
#         "eta": -1.145175
#     },
#     "13": {
#         "cp_num": 15,
#         "element": "H",
#         "number": "14",
#         "pos_ang": [
#             1.613032888933,
#             -0.92581039821,
#             -1.289099415949
#         ],
#         "density_all": 0.3912283139,
#         "density_alpha": 0.1956141569,
#         "density_beta": 0.1956141569,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.008122213203,
#         "Hamiltonian_K": 3.184737772,
#         "energy_density": -3.184737772,
#         "lap_e_density": -12.70646223,
#         "e_loc_func": 0.999816867,
#         "lol": 0.9866630194,
#         "ave_loc_ion_E": 0.399617224,
#         "delta_g_promolecular": 0.1151544524,
#         "delta_g_hirsh": 0.2276521009,
#         "esp_nuc": 31.59371382,
#         "esp_e": -14.08058708,
#         "esp_total": 17.51312674,
#         "grad_norm": 8.350254466e-16,
#         "lap_norm": -12.70646223,
#         "eig_hess": -12.706462234,
#         "det_hessian": -75.52855235,
#         "ellip_e_dens": 0.001021,
#         "eta": -1.145163
#     },
#     "14": {
#         "cp_num": 1,
#         "element": "H",
#         "number": "15",
#         "pos_ang": [
#             0.049696203174,
#             -2.903745221316,
#             0.057501569739
#         ],
#         "density_all": 0.3915529004,
#         "density_alpha": 0.1957764502,
#         "density_beta": 0.1957764502,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.007808946894,
#         "Hamiltonian_K": 3.203180367,
#         "energy_density": -3.203180367,
#         "lap_e_density": -12.78148568,
#         "e_loc_func": 0.9998311694,
#         "lol": 0.9871883084,
#         "ave_loc_ion_E": 0.4099430862,
#         "delta_g_promolecular": 0.1149949118,
#         "delta_g_hirsh": 0.2286566865,
#         "esp_nuc": 31.65776271,
#         "esp_e": -14.38563489,
#         "esp_total": 17.27212783,
#         "grad_norm": 1.058238906e-15,
#         "lap_norm": -12.78148568,
#         "eig_hess": -12.781485681000001,
#         "det_hessian": -76.86871629,
#         "ellip_e_dens": 0.000223,
#         "eta": -1.145655
#     },
#     "15": {
#         "cp_num": 10,
#         "element": "H",
#         "number": "16",
#         "pos_ang": [
#             1.732262238522,
#             -0.849634857803,
#             1.201993763335
#         ],
#         "density_all": 0.3920157204,
#         "density_alpha": 0.1960078602,
#         "density_beta": 0.1960078602,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.007935139846,
#         "Hamiltonian_K": 3.197889639,
#         "energy_density": -3.197889639,
#         "lap_e_density": -12.759818,
#         "e_loc_func": 0.9998263617,
#         "lol": 0.9870092346,
#         "ave_loc_ion_E": 0.4084483362,
#         "delta_g_promolecular": 0.1156171665,
#         "delta_g_hirsh": 0.2299220792,
#         "esp_nuc": 32.39849768,
#         "esp_e": -15.10599086,
#         "esp_total": 17.29250682,
#         "grad_norm": 1.011194628e-15,
#         "lap_norm": -12.759818,
#         "eig_hess": -12.759817997,
#         "det_hessian": -76.47402138,
#         "ellip_e_dens": 0.000885,
#         "eta": -1.14678
#     },
#     "16": {
#         "cp_num": 3,
#         "element": "H",
#         "number": "17",
#         "pos_ang": [
#             0.051925598362,
#             -1.576441956788,
#             3.103474985703
#         ],
#         "density_all": 0.3913267226,
#         "density_alpha": 0.1956633613,
#         "density_beta": 0.1956633613,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.008459135387,
#         "Hamiltonian_K": 3.181715247,
#         "energy_density": -3.181715247,
#         "lap_e_density": -12.69302445,
#         "e_loc_func": 0.9998015476,
#         "lol": 0.9861231981,
#         "ave_loc_ion_E": 0.4124010709,
#         "delta_g_promolecular": 0.1195202413,
#         "delta_g_hirsh": 0.2377755083,
#         "esp_nuc": 31.2319208,
#         "esp_e": -14.31196661,
#         "esp_total": 16.91995419,
#         "grad_norm": 6.325344005e-16,
#         "lap_norm": -12.69302445,
#         "eig_hess": -12.693024444999999,
#         "det_hessian": -75.26400186,
#         "ellip_e_dens": 0.001548,
#         "eta": -1.149768
#     },
#     "17": {
#         "cp_num": 11,
#         "element": "H",
#         "number": "18",
#         "pos_ang": [
#             -1.644906885184,
#             0.191112439148,
#             3.535919617622
#         ],
#         "density_all": 0.3904671755,
#         "density_alpha": 0.1952335877,
#         "density_beta": 0.1952335877,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.008343290511,
#         "Hamiltonian_K": 3.165773464,
#         "energy_density": -3.165773464,
#         "lap_e_density": -12.62972069,
#         "e_loc_func": 0.9998055184,
#         "lol": 0.9862610636,
#         "ave_loc_ion_E": 0.4126667347,
#         "delta_g_promolecular": 0.1194642686,
#         "delta_g_hirsh": 0.2372840897,
#         "esp_nuc": 30.1761696,
#         "esp_e": -13.27133528,
#         "esp_total": 16.90483432,
#         "grad_norm": 8.939025401e-16,
#         "lap_norm": -12.62972069,
#         "eig_hess": -12.629720694,
#         "det_hessian": -74.13237403,
#         "ellip_e_dens": 0.001202,
#         "eta": -1.151477
#     },
#     "18": {
#         "cp_num": 17,
#         "element": "H",
#         "number": "19",
#         "pos_ang": [
#             -1.03314062736,
#             1.154796755783,
#             2.193674295258
#         ],
#         "density_all": 0.3932250571,
#         "density_alpha": 0.1966125286,
#         "density_beta": 0.1966125286,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.009000567672,
#         "Hamiltonian_K": 3.186853171,
#         "energy_density": -3.186853171,
#         "lap_e_density": -12.71141041,
#         "e_loc_func": 0.9997789619,
#         "lol": 0.9853648756,
#         "ave_loc_ion_E": 0.4126040209,
#         "delta_g_promolecular": 0.1217659215,
#         "delta_g_hirsh": 0.2431667409,
#         "esp_nuc": 31.7600394,
#         "esp_e": -14.94817914,
#         "esp_total": 16.81186026,
#         "grad_norm": 8.949013927e-16,
#         "lap_norm": -12.71141041,
#         "eig_hess": -12.711410415,
#         "det_hessian": -75.57282022,
#         "ellip_e_dens": 0.000822,
#         "eta": -1.152484
#     },
#     "19": {
#         "cp_num": 2,
#         "element": "H",
#         "number": "20",
#         "pos_ang": [
#             -2.338203092741,
#             -1.623188929273,
#             1.981286767864
#         ],
#         "density_all": 0.3913573258,
#         "density_alpha": 0.1956786629,
#         "density_beta": 0.1956786629,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.00846152302,
#         "Hamiltonian_K": 3.181875165,
#         "energy_density": -3.181875165,
#         "lap_e_density": -12.69365457,
#         "e_loc_func": 0.9998014874,
#         "lol": 0.9861211196,
#         "ave_loc_ion_E": 0.4124375178,
#         "delta_g_promolecular": 0.1195543384,
#         "delta_g_hirsh": 0.2378631674,
#         "esp_nuc": 31.22949351,
#         "esp_e": -14.31213701,
#         "esp_total": 16.9173565,
#         "grad_norm": 1.476407399e-15,
#         "lap_norm": -12.69365457,
#         "eig_hess": -12.693654566,
#         "det_hessian": -75.27504085,
#         "ellip_e_dens": 0.001549,
#         "eta": -1.149797
#     },
#     "20": {
#         "cp_num": 9,
#         "element": "H",
#         "number": "21",
#         "pos_ang": [
#             -1.971153840584,
#             -0.923053078565,
#             -0.53712069748
#         ],
#         "density_all": 0.3919776023,
#         "density_alpha": 0.1959888012,
#         "density_beta": 0.1959888012,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.007932495189,
#         "Hamiltonian_K": 3.197708174,
#         "energy_density": -3.197708174,
#         "lap_e_density": -12.75910272,
#         "e_loc_func": 0.999826421,
#         "lol": 0.9870114304,
#         "ave_loc_ion_E": 0.4084054464,
#         "delta_g_promolecular": 0.1155724996,
#         "delta_g_hirsh": 0.2298095657,
#         "esp_nuc": 32.40131987,
#         "esp_e": -15.10537547,
#         "esp_total": 17.2959444,
#         "grad_norm": 5.5423537e-16,
#         "lap_norm": -12.75910272,
#         "eig_hess": -12.759102717,
#         "det_hessian": -76.46138245,
#         "ellip_e_dens": 0.000886,
#         "eta": -1.146743
#     },
#     "3_14": {
#         "cp_num": 22,
#         "connected_bond_paths": [
#             15,
#             4
#         ],
#         "pos_ang": [
#             0.04947270768,
#             -2.515578314372,
#             0.041679258494
#         ],
#         "density_all": 0.2744496711,
#         "density_alpha": 0.1372248356,
#         "density_beta": 0.1372248356,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04124122122,
#         "Hamiltonian_K": 0.2876572383,
#         "energy_density": -0.2876572383,
#         "lap_e_density": -0.9856640682,
#         "e_loc_func": 0.9848676881,
#         "lol": 0.8897392022,
#         "ave_loc_ion_E": 0.4380499856,
#         "delta_g_promolecular": 0.269072552,
#         "delta_g_hirsh": 0.4820846211,
#         "esp_nuc": 17.46909755,
#         "esp_e": -16.63695113,
#         "esp_total": 0.8321464153,
#         "grad_norm": 2.029218692e-16,
#         "lap_norm": -0.9856640682,
#         "eig_hess": -0.9856640682,
#         "det_hessian": 0.1604417138,
#         "ellip_e_dens": 0.002197,
#         "eta": 1.885093
#     },
#     "7_19": {
#         "cp_num": 23,
#         "connected_bond_paths": [
#             20,
#             8
#         ],
#         "pos_ang": [
#             -2.064198890338,
#             -1.379847949686,
#             1.870671641135
#         ],
#         "density_all": 0.2772942843,
#         "density_alpha": 0.1386471422,
#         "density_beta": 0.1386471422,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04556159989,
#         "Hamiltonian_K": 0.2939435678,
#         "energy_density": -0.2939435678,
#         "lap_e_density": -0.9935278715,
#         "e_loc_func": 0.9822042301,
#         "lol": 0.8813878349,
#         "ave_loc_ion_E": 0.4374557887,
#         "delta_g_promolecular": 0.2751973855,
#         "delta_g_hirsh": 0.4882190899,
#         "esp_nuc": 17.3890669,
#         "esp_e": -16.54578171,
#         "esp_total": 0.8432851896,
#         "grad_norm": 1.926343834e-16,
#         "lap_norm": -0.9935278715,
#         "eig_hess": -0.9935278715000001,
#         "det_hessian": 0.1596194578,
#         "ellip_e_dens": 0.037854,
#         "eta": 1.944663
#     },
#     "5_16": {
#         "cp_num": 24,
#         "connected_bond_paths": [
#             17,
#             6
#         ],
#         "pos_ang": [
#             -0.045721756668,
#             -1.340294512851,
#             2.81842110101
#         ],
#         "density_all": 0.2772528369,
#         "density_alpha": 0.1386264185,
#         "density_beta": 0.1386264185,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04555114059,
#         "Hamiltonian_K": 0.2938525355,
#         "energy_density": -0.2938525355,
#         "lap_e_density": -0.9932055795,
#         "e_loc_func": 0.982203545,
#         "lol": 0.8813857915,
#         "ave_loc_ion_E": 0.437428155,
#         "delta_g_promolecular": 0.2751635603,
#         "delta_g_hirsh": 0.4881559734,
#         "esp_nuc": 17.38880482,
#         "esp_e": -16.54568256,
#         "esp_total": 0.8431222577,
#         "grad_norm": 2.168894349e-16,
#         "lap_norm": -0.9932055795,
#         "eig_hess": -0.9932055795999999,
#         "det_hessian": 0.1595642582,
#         "ellip_e_dens": 0.037831,
#         "eta": 1.944052
#     },
#     "5_7": {
#         "cp_num": 25,
#         "connected_bond_paths": [
#             8,
#             6
#         ],
#         "pos_ang": [
#             -0.896702498974,
#             -0.995163237089,
#             1.992216455884
#         ],
#         "density_all": 0.236211327,
#         "density_alpha": 0.1181056635,
#         "density_beta": 0.1181056635,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.08809416796,
#         "Hamiltonian_K": 0.1886048386,
#         "energy_density": -0.1886048386,
#         "lap_e_density": -0.4020426824,
#         "e_loc_func": 0.896400978,
#         "lol": 0.7463129281,
#         "ave_loc_ion_E": 0.488915337,
#         "delta_g_promolecular": 0.3144641988,
#         "delta_g_hirsh": 0.4459997772,
#         "esp_nuc": 21.03179584,
#         "esp_e": -20.3459183,
#         "esp_total": 0.6858775406,
#         "grad_norm": 2.221529987e-17,
#         "lap_norm": -0.4020426824,
#         "eig_hess": -0.40204268249999997,
#         "det_hessian": 0.04052967877,
#         "ellip_e_dens": 0.425007,
#         "eta": 1.324923
#     },
#     "3_8": {
#         "cp_num": 26,
#         "connected_bond_paths": [
#             4,
#             9
#         ],
#         "pos_ang": [
#             -0.607110502517,
#             -1.412238939319,
#             0.104743547561
#         ],
#         "density_all": 0.225100336,
#         "density_alpha": 0.112550168,
#         "density_beta": 0.112550168,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.06062815669,
#         "Hamiltonian_K": 0.1737789511,
#         "energy_density": -0.1737789511,
#         "lap_e_density": -0.4526031776,
#         "e_loc_func": 0.9395990769,
#         "lol": 0.7977659175,
#         "ave_loc_ion_E": 0.4374385375,
#         "delta_g_promolecular": 0.2899651514,
#         "delta_g_hirsh": 0.4322960091,
#         "esp_nuc": 21.24893517,
#         "esp_e": -20.67691594,
#         "esp_total": 0.5720192302,
#         "grad_norm": 1.327715238e-16,
#         "lap_norm": -0.4526031776,
#         "eig_hess": -0.4526031775,
#         "det_hessian": 0.04514631313,
#         "ellip_e_dens": 0.015503,
#         "eta": 1.238767
#     },
#     "3_4": {
#         "cp_num": 27,
#         "connected_bond_paths": [
#             4,
#             5
#         ],
#         "pos_ang": [
#             0.38412456146,
#             -1.392633175902,
#             0.570251823188
#         ],
#         "density_all": 0.2251534351,
#         "density_alpha": 0.1125767175,
#         "density_beta": 0.1125767175,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.06064309008,
#         "Hamiltonian_K": 0.1738444092,
#         "energy_density": -0.1738444092,
#         "lap_e_density": -0.4528052765,
#         "e_loc_func": 0.9396157446,
#         "lol": 0.7977896044,
#         "ave_loc_ion_E": 0.4374759738,
#         "delta_g_promolecular": 0.2900244625,
#         "delta_g_hirsh": 0.4323834399,
#         "esp_nuc": 21.2493509,
#         "esp_e": -20.67715328,
#         "esp_total": 0.5721976184,
#         "grad_norm": 8.970651036e-17,
#         "lap_norm": -0.4528052765,
#         "eig_hess": -0.4528052763999999,
#         "det_hessian": 0.04518286027,
#         "ellip_e_dens": 0.015486,
#         "eta": 1.238972
#     },
#     "7_8": {
#         "cp_num": 28,
#         "connected_bond_paths": [
#             8,
#             9
#         ],
#         "pos_ang": [
#             -1.402167957714,
#             -0.918492419215,
#             0.928316793242
#         ],
#         "density_all": 0.2443748423,
#         "density_alpha": 0.1221874211,
#         "density_beta": 0.1221874211,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.05900971692,
#         "Hamiltonian_K": 0.1927622282,
#         "energy_density": -0.1927622282,
#         "lap_e_density": -0.5350100451,
#         "e_loc_func": 0.9557402818,
#         "lol": 0.8229371488,
#         "ave_loc_ion_E": 0.4499672102,
#         "delta_g_promolecular": 0.3242065613,
#         "delta_g_hirsh": 0.463417652,
#         "esp_nuc": 20.91810016,
#         "esp_e": -20.28766511,
#         "esp_total": 0.6304350545,
#         "grad_norm": 8.666377309e-17,
#         "lap_norm": -0.5350100451,
#         "eig_hess": -0.5350100450999999,
#         "det_hessian": 0.05927480489,
#         "ellip_e_dens": 0.058334,
#         "eta": 1.366847
#     },
#     "4_5": {
#         "cp_num": 29,
#         "connected_bond_paths": [
#             6,
#             5
#         ],
#         "pos_ang": [
#             0.241798798615,
#             -0.886047627199,
#             1.70038637643
#         ],
#         "density_all": 0.2443806333,
#         "density_alpha": 0.1221903166,
#         "density_beta": 0.1221903166,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.05900958859,
#         "Hamiltonian_K": 0.1927707248,
#         "energy_density": -0.1927707248,
#         "lap_e_density": -0.535044545,
#         "e_loc_func": 0.955743807,
#         "lol": 0.8229432204,
#         "ave_loc_ion_E": 0.4499646215,
#         "delta_g_promolecular": 0.3242148865,
#         "delta_g_hirsh": 0.4634283313,
#         "esp_nuc": 20.91816189,
#         "esp_e": -20.28771609,
#         "esp_total": 0.6304457946,
#         "grad_norm": 1.080587924e-16,
#         "lap_norm": -0.535044545,
#         "eig_hess": -0.5350445450000001,
#         "det_hessian": 0.05928185515,
#         "ellip_e_dens": 0.058308,
#         "eta": 1.366867
#     },
#     "2_3": {
#         "cp_num": 31,
#         "connected_bond_paths": [
#             4,
#             3
#         ],
#         "pos_ang": [
#             0.319094468738,
#             -1.430045310511,
#             -0.57814290721
#         ],
#         "density_all": 0.2388175038,
#         "density_alpha": 0.1194087519,
#         "density_beta": 0.1194087519,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.06360509744,
#         "Hamiltonian_K": 0.1907352998,
#         "energy_density": -0.1907352998,
#         "lap_e_density": -0.5085208094,
#         "e_loc_func": 0.9450998263,
#         "lol": 0.8058152121,
#         "ave_loc_ion_E": 0.4492064342,
#         "delta_g_promolecular": 0.3041427445,
#         "delta_g_hirsh": 0.4533697662,
#         "esp_nuc": 20.2201808,
#         "esp_e": -19.59493758,
#         "esp_total": 0.625243222,
#         "grad_norm": 8.735871121e-17,
#         "lap_norm": -0.5085208094,
#         "eig_hess": -0.5085208095,
#         "det_hessian": 0.0550760176,
#         "ellip_e_dens": 0.008137,
#         "eta": 1.298492
#     },
#     "6_7": {
#         "cp_num": 32,
#         "connected_bond_paths": [
#             8,
#             7
#         ],
#         "pos_ang": [
#             -1.433799886946,
#             -0.357206181962,
#             2.10796090382
#         ],
#         "density_all": 0.2340239435,
#         "density_alpha": 0.1170119717,
#         "density_beta": 0.1170119717,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.08545438071,
#         "Hamiltonian_K": 0.184945972,
#         "energy_density": -0.184945972,
#         "lap_e_density": -0.3979663652,
#         "e_loc_func": 0.8991385033,
#         "lol": 0.7491269504,
#         "ave_loc_ion_E": 0.4975445759,
#         "delta_g_promolecular": 0.3122570359,
#         "delta_g_hirsh": 0.4406450868,
#         "esp_nuc": 20.07472238,
#         "esp_e": -19.37919553,
#         "esp_total": 0.6955268524,
#         "grad_norm": 1.535064881e-16,
#         "lap_norm": -0.3979663652,
#         "eig_hess": -0.3979663653,
#         "det_hessian": 0.0371629352,
#         "ellip_e_dens": 0.508347,
#         "eta": 1.374248
#     },
#     "5_6": {
#         "cp_num": 33,
#         "connected_bond_paths": [
#             6,
#             7
#         ],
#         "pos_ang": [
#             -0.663427124402,
#             -0.342041080275,
#             2.469795135446
#         ],
#         "density_all": 0.2341063339,
#         "density_alpha": 0.117053167,
#         "density_beta": 0.117053167,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.08546892127,
#         "Hamiltonian_K": 0.1850605841,
#         "energy_density": -0.1850605841,
#         "lap_e_density": -0.3983666514,
#         "e_loc_func": 0.8992140292,
#         "lol": 0.7492052216,
#         "ave_loc_ion_E": 0.4975465587,
#         "delta_g_promolecular": 0.3123196469,
#         "delta_g_hirsh": 0.4407751282,
#         "esp_nuc": 20.07513236,
#         "esp_e": -19.37937221,
#         "esp_total": 0.6957601543,
#         "grad_norm": 1.541465559e-16,
#         "lap_norm": -0.3983666514,
#         "eig_hess": -0.3983666514,
#         "det_hessian": 0.03722479196,
#         "ellip_e_dens": 0.507544,
#         "eta": 1.374559
#     },
#     "8_20": {
#         "cp_num": 34,
#         "connected_bond_paths": [
#             9,
#             21
#         ],
#         "pos_ang": [
#             -1.689651362724,
#             -0.916692256405,
#             -0.271067607078
#         ],
#         "density_all": 0.275319897,
#         "density_alpha": 0.1376599485,
#         "density_beta": 0.1376599485,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04246030757,
#         "Hamiltonian_K": 0.2891086775,
#         "energy_density": -0.2891086775,
#         "lap_e_density": -0.9865934797,
#         "e_loc_func": 0.9841401674,
#         "lol": 0.8873770859,
#         "ave_loc_ion_E": 0.4360524939,
#         "delta_g_promolecular": 0.271029923,
#         "delta_g_hirsh": 0.485541194,
#         "esp_nuc": 18.2164896,
#         "esp_e": -17.38825901,
#         "esp_total": 0.8282305945,
#         "grad_norm": 5.50488639e-17,
#         "lap_norm": -0.9865934797,
#         "eig_hess": -0.9865934796000002,
#         "det_hessian": 0.1611639464,
#         "ellip_e_dens": 0.016198,
#         "eta": 1.896584
#     },
#     "4_15": {
#         "cp_num": 35,
#         "connected_bond_paths": [
#             5,
#             16
#         ],
#         "pos_ang": [
#             1.34780202178,
#             -0.856514626177,
#             1.155336463503
#         ],
#         "density_all": 0.2753726381,
#         "density_alpha": 0.1376863191,
#         "density_beta": 0.1376863191,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04247279366,
#         "Hamiltonian_K": 0.289226491,
#         "energy_density": -0.289226491,
#         "lap_e_density": -0.9870147894,
#         "e_loc_func": 0.9841409568,
#         "lol": 0.8873796063,
#         "ave_loc_ion_E": 0.4360905993,
#         "delta_g_promolecular": 0.2710716223,
#         "delta_g_hirsh": 0.485617637,
#         "esp_nuc": 18.21719859,
#         "esp_e": -17.38874728,
#         "esp_total": 0.8284513092,
#         "grad_norm": 1.130618585e-16,
#         "lap_norm": -0.9870147894,
#         "eig_hess": -0.9870147893999999,
#         "det_hessian": 0.1612366799,
#         "ellip_e_dens": 0.016192,
#         "eta": 1.897333
#     },
#     "6_17": {
#         "cp_num": 40,
#         "connected_bond_paths": [
#             18,
#             7
#         ],
#         "pos_ang": [
#             -1.483048655037,
#             0.185666433084,
#             3.191558939083
#         ],
#         "density_all": 0.2777110007,
#         "density_alpha": 0.1388555003,
#         "density_beta": 0.1388555003,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04423022195,
#         "Hamiltonian_K": 0.2959933258,
#         "energy_density": -0.2959933258,
#         "lap_e_density": -1.007052415,
#         "e_loc_func": 0.9832940737,
#         "lol": 0.8847088988,
#         "ave_loc_ion_E": 0.4371868443,
#         "delta_g_promolecular": 0.2779286916,
#         "delta_g_hirsh": 0.4925804531,
#         "esp_nuc": 16.17941302,
#         "esp_e": -15.34057982,
#         "esp_total": 0.8388332033,
#         "grad_norm": 3.28942365e-17,
#         "lap_norm": -1.007052415,
#         "eig_hess": -1.0070524153,
#         "det_hessian": 0.1619342627,
#         "ellip_e_dens": 0.031689,
#         "eta": 1.963917
#     },
#     "1_8": {
#         "cp_num": 41,
#         "connected_bond_paths": [
#             9,
#             2
#         ],
#         "pos_ang": [
#             -0.614727622694,
#             -0.38436424783,
#             0.07898613138
#         ],
#         "density_all": 0.2222272839,
#         "density_alpha": 0.111113642,
#         "density_beta": 0.111113642,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.05998622603,
#         "Hamiltonian_K": 0.1698324438,
#         "energy_density": -0.1698324438,
#         "lap_e_density": -0.4393848709,
#         "e_loc_func": 0.938365378,
#         "lol": 0.7960235967,
#         "ave_loc_ion_E": 0.4429012247,
#         "delta_g_promolecular": 0.2855922556,
#         "delta_g_hirsh": 0.4270194765,
#         "esp_nuc": 21.8441897,
#         "esp_e": -21.27287773,
#         "esp_total": 0.5713119719,
#         "grad_norm": 7.259149016e-17,
#         "lap_norm": -0.4393848709,
#         "eig_hess": -0.4393848709,
#         "det_hessian": 0.04287139063,
#         "ellip_e_dens": 0.005124,
#         "eta": 1.217661
#     },
#     "1_4": {
#         "cp_num": 42,
#         "connected_bond_paths": [
#             5,
#             2
#         ],
#         "pos_ang": [
#             0.375300060427,
#             -0.36477417989,
#             0.54396761727
#         ],
#         "density_all": 0.2221538979,
#         "density_alpha": 0.111076949,
#         "density_beta": 0.111076949,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.05996663469,
#         "Hamiltonian_K": 0.1697450114,
#         "energy_density": -0.1697450114,
#         "lap_e_density": -0.4391135069,
#         "e_loc_func": 0.9383394767,
#         "lol": 0.7959872522,
#         "ave_loc_ion_E": 0.4428668993,
#         "delta_g_promolecular": 0.2855155176,
#         "delta_g_hirsh": 0.4268971208,
#         "esp_nuc": 21.84357445,
#         "esp_e": -21.27247667,
#         "esp_total": 0.5710977831,
#         "grad_norm": 1.182337538e-16,
#         "lap_norm": -0.4391135069,
#         "eig_hess": -0.4391135069,
#         "det_hessian": 0.04282022102,
#         "ellip_e_dens": 0.005081,
#         "eta": 1.217376
#     },
#     "2_12": {
#         "cp_num": 43,
#         "connected_bond_paths": [
#             3,
#             13
#         ],
#         "pos_ang": [
#             0.217773622123,
#             -0.949081404092,
#             -1.695576261183
#         ],
#         "density_all": 0.2736356781,
#         "density_alpha": 0.1368178391,
#         "density_beta": 0.1368178391,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04450433442,
#         "Hamiltonian_K": 0.2867900713,
#         "energy_density": -0.2867900713,
#         "lap_e_density": -0.9691429477,
#         "e_loc_func": 0.9822509154,
#         "lol": 0.8815281019,
#         "ave_loc_ion_E": 0.4283555076,
#         "delta_g_promolecular": 0.2678146772,
#         "delta_g_hirsh": 0.479635606,
#         "esp_nuc": 16.94583902,
#         "esp_e": -16.12792542,
#         "esp_total": 0.8179136053,
#         "grad_norm": 1.120458951e-16,
#         "lap_norm": -0.9691429477,
#         "eig_hess": -0.9691429476,
#         "det_hessian": 0.1554812188,
#         "ellip_e_dens": 0.020546,
#         "eta": 1.884606
#     },
#     "2_13": {
#         "cp_num": 44,
#         "connected_bond_paths": [
#             3,
#             14
#         ],
#         "pos_ang": [
#             1.227778845987,
#             -0.929078682654,
#             -1.221231628631
#         ],
#         "density_all": 0.2736175743,
#         "density_alpha": 0.1368087871,
#         "density_beta": 0.1368087871,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04449824109,
#         "Hamiltonian_K": 0.2867490148,
#         "energy_density": -0.2867490148,
#         "lap_e_density": -0.969003095,
#         "e_loc_func": 0.9822518437,
#         "lol": 0.8815308855,
#         "ave_loc_ion_E": 0.4283389942,
#         "delta_g_promolecular": 0.2678060363,
#         "delta_g_hirsh": 0.4796159117,
#         "esp_nuc": 16.94549865,
#         "esp_e": -16.12766331,
#         "esp_total": 0.8178353355,
#         "grad_norm": 2.782483133e-16,
#         "lap_norm": -0.969003095,
#         "eig_hess": -0.9690030949000001,
#         "det_hessian": 0.155459756,
#         "ellip_e_dens": 0.020554,
#         "eta": 1.884349
#     },
#     "1_2": {
#         "cp_num": 45,
#         "connected_bond_paths": [
#             3,
#             2
#         ],
#         "pos_ang": [
#             0.309537425453,
#             -0.407603758479,
#             -0.601085075687
#         ],
#         "density_all": 0.2337106314,
#         "density_alpha": 0.1168553157,
#         "density_beta": 0.1168553157,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.06142772218,
#         "Hamiltonian_K": 0.1838973426,
#         "energy_density": -0.1838973426,
#         "lap_e_density": -0.4898784817,
#         "e_loc_func": 0.9449751907,
#         "lol": 0.8056282798,
#         "ave_loc_ion_E": 0.442140235,
#         "delta_g_promolecular": 0.2993412662,
#         "delta_g_hirsh": 0.4462872586,
#         "esp_nuc": 20.80197536,
#         "esp_e": -20.2031142,
#         "esp_total": 0.5988611579,
#         "grad_norm": 1.30980544e-16,
#         "lap_norm": -0.4898784817,
#         "eig_hess": -0.4898784817,
#         "det_hessian": 0.05150414249,
#         "ellip_e_dens": 0.002657,
#         "eta": 1.275139
#     },
#     "6_18": {
#         "cp_num": 46,
#         "connected_bond_paths": [
#             7,
#             19
#         ],
#         "pos_ang": [
#             -1.089466744839,
#             0.806700740686,
#             2.327955509993
#         ],
#         "density_all": 0.2807502914,
#         "density_alpha": 0.1403751457,
#         "density_beta": 0.1403751457,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04483029575,
#         "Hamiltonian_K": 0.3019776764,
#         "energy_density": -0.3019776764,
#         "lap_e_density": -1.028589523,
#         "e_loc_func": 0.9834467519,
#         "lol": 0.885183891,
#         "ave_loc_ion_E": 0.4358471216,
#         "delta_g_promolecular": 0.2813457775,
#         "delta_g_hirsh": 0.4982816566,
#         "esp_nuc": 17.37637965,
#         "esp_e": -16.52935114,
#         "esp_total": 0.8470285073,
#         "grad_norm": 2.68837368e-16,
#         "lap_norm": -1.028589523,
#         "eig_hess": -1.0285895227,
#         "det_hessian": 0.1677171127,
#         "ellip_e_dens": 0.028343,
#         "eta": 1.988354
#     },
#     "0_1": {
#         "cp_num": 48,
#         "connected_bond_paths": [
#             2,
#             1
#         ],
#         "pos_ang": [
#             0.056457766305,
#             0.797922738347,
#             -0.113549874682
#         ],
#         "density_all": 0.2480738233,
#         "density_alpha": 0.1240369117,
#         "density_beta": 0.1240369117,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.05707065685,
#         "Hamiltonian_K": 0.1980804834,
#         "energy_density": -0.1980804834,
#         "lap_e_density": -0.5640393063,
#         "e_loc_func": 0.9604296545,
#         "lol": 0.8312939461,
#         "ave_loc_ion_E": 0.4576679897,
#         "delta_g_promolecular": 0.3328790948,
#         "delta_g_hirsh": 0.4681755127,
#         "esp_nuc": 19.83866164,
#         "esp_e": -19.18337211,
#         "esp_total": 0.6552895318,
#         "grad_norm": 1.800277143e-16,
#         "lap_norm": -0.5640393063,
#         "eig_hess": -0.5640393063,
#         "det_hessian": 0.0649295269,
#         "ellip_e_dens": 0.008563,
#         "eta": 1.36806
#     },
#     "11_18": {
#         "cp_num": 49,
#         "connected_bond_paths": [
#             19,
#             12
#         ],
#         "pos_ang": [
#             -0.662013356687,
#             1.542430546178,
#             1.382257877662
#         ],
#         "density_all": 0.01350594284,
#         "density_alpha": 0.00675297142,
#         "density_beta": 0.00675297142,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.009733048857,
#         "Hamiltonian_K": -0.0006066258375,
#         "energy_density": 0.0006066258375,
#         "lap_e_density": 0.04135869878,
#         "e_loc_func": 0.04848202703,
#         "lol": 0.1843114202,
#         "ave_loc_ion_E": 0.4170373633,
#         "delta_g_promolecular": 0.03618385486,
#         "delta_g_hirsh": 0.0266266017,
#         "esp_nuc": 13.97168653,
#         "esp_e": -13.91070996,
#         "esp_total": 0.06097656437,
#         "grad_norm": 3.003161735e-18,
#         "lap_norm": 0.04135869878,
#         "eig_hess": 0.041358698779999994,
#         "det_hessian": 1.502271293e-05,
#         "ellip_e_dens": 0.239047,
#         "eta": 0.229584
#     },
#     "0_11": {
#         "cp_num": 50,
#         "connected_bond_paths": [
#             1,
#             12
#         ],
#         "pos_ang": [
#             -0.167207786305,
#             1.893416927283,
#             0.310930268073
#         ],
#         "density_all": 0.2744135804,
#         "density_alpha": 0.1372067902,
#         "density_beta": 0.1372067902,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04585735228,
#         "Hamiltonian_K": 0.2908184384,
#         "energy_density": -0.2908184384,
#         "lap_e_density": -0.9798443445,
#         "e_loc_func": 0.9813501438,
#         "lol": 0.8788690252,
#         "ave_loc_ion_E": 0.433749139,
#         "delta_g_promolecular": 0.2717732938,
#         "delta_g_hirsh": 0.4826184465,
#         "esp_nuc": 16.53000496,
#         "esp_e": -15.70086271,
#         "esp_total": 0.8291422517,
#         "grad_norm": 4.152766778e-17,
#         "lap_norm": -0.9798443445,
#         "eig_hess": -0.9798443444999999,
#         "det_hessian": 0.1560289668,
#         "ellip_e_dens": 0.00168,
#         "eta": 1.893798
#     },
#     "0_10": {
#         "cp_num": 51,
#         "connected_bond_paths": [
#             1,
#             11
#         ],
#         "pos_ang": [
#             -0.259603137855,
#             1.724023206385,
#             -0.766504105587
#         ],
#         "density_all": 0.2715156128,
#         "density_alpha": 0.1357578064,
#         "density_beta": 0.1357578064,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04533734145,
#         "Hamiltonian_K": 0.2853297016,
#         "energy_density": -0.2853297016,
#         "lap_e_density": -0.9599694408,
#         "e_loc_func": 0.9811184105,
#         "lol": 0.8781978014,
#         "ave_loc_ion_E": 0.4327863582,
#         "delta_g_promolecular": 0.2700001672,
#         "delta_g_hirsh": 0.4785871381,
#         "esp_nuc": 16.10824596,
#         "esp_e": -15.28894674,
#         "esp_total": 0.8192992211,
#         "grad_norm": 1.203927306e-16,
#         "lap_norm": -0.9599694408,
#         "eig_hess": -0.9599694407999999,
#         "det_hessian": 0.1511704871,
#         "ellip_e_dens": 0.001355,
#         "eta": 1.866621
#     },
#     "0_9": {
#         "cp_num": 52,
#         "connected_bond_paths": [
#             1,
#             10
#         ],
#         "pos_ang": [
#             0.730339925193,
#             1.744554461894,
#             -0.297679386228
#         ],
#         "density_all": 0.2715406444,
#         "density_alpha": 0.1357703222,
#         "density_beta": 0.1357703222,
#         "spin_density": 0.0,
#         "Lagrangian_K": 0.04534110605,
#         "Hamiltonian_K": 0.2853884766,
#         "energy_density": -0.2853884766,
#         "lap_e_density": -0.9601894821,
#         "e_loc_func": 0.9811210272,
#         "lol": 0.8782053545,
#         "ave_loc_ion_E": 0.4328095501,
#         "delta_g_promolecular": 0.2700315102,
#         "delta_g_hirsh": 0.4786301849,
#         "esp_nuc": 16.10920944,
#         "esp_e": -15.28977258,
#         "esp_total": 0.8194368651,
#         "grad_norm": 1.327613225e-16,
#         "lap_norm": -0.9601894821,
#         "eig_hess": -0.9601894822000001,
#         "det_hessian": 0.1511926955,
#         "ellip_e_dens": 0.001331,
#         "eta": 1.867079
#     }
# }

# %%
print("Other Data:")
print(json.dumps(other_data, indent=4))
# Out:
# Other Data:
# {
#     "mpp_full": 0.9424,
#     "sdp_full": 4.146655,
#     "mpp_heavy": 0.605341,
#     "sdp_heavy": 2.073794,
#     "ESP_Volume": 1146.86739,
#     "ESP_Surface_Density": 1.1744,
#     "ESP_Minimal_value": -11.87678,
#     "ESP_Maximal_value": 10.00567,
#     "ESP_Overall_surface_area": 604.06464,
#     "ESP_Positive_surface_area": 398.1284,
#     "ESP_Negative_surface_area": 205.93624,
#     "ESP_Overall_average_value": 0.00178228,
#     "ESP_Positive_average_value": 0.00539383,
#     "ESP_Negative_average_value": -0.00519978,
#     "ESP_Overall_variance": 3.383e-05,
#     "ESP_Positive_variance": 1.295e-05,
#     "ESP_Negative_variance": 2.088e-05,
#     "ESP_Balance_of_charges": 0.23627292,
#     "ESP_Product_of_sigma": 7.99e-06,
#     "ESP_Internal_charge_separation": 0.00498071,
#     "ESP_Molecular_polarity_index": 0.14497344,
#     "ESP_Nonpolar_surface_area": 166.44,
#     "ESP_Polar_surface_area": 2.72,
#     "ESP_Overall_skewness": -0.8572460633,
#     "ESP_Positive_skewness": 0.4365975705,
#     "ESP_Negative_skewness": -1.245643728,
#     "ALIE_Volume": 1147.45553,
#     "ALIE_Surface_Density": 1.1738,
#     "ALIE_Minimal_value": 8.64471,
#     "ALIE_Maximal_value": 12.41077,
#     "ALIE_Overall_surface_area": 604.20967,
#     "ALIE_Positive_surface_area": 604.20967,
#     "ALIE_Negative_surface_area": 0.0,
#     "ALIE_Overall_skewness": 0.2901892795,
#     "ALIE_Positive_skewness": 0.2901892795
# }

# %%
print("Charge Data:")
print(json.dumps(charges_data, indent=4))
# Out:
# Charge Data:
# {
#     "becke": {
#         "charge": {
#             "1_C": -0.25223672,
#             "2_C": 0.13691401,
#             "3_C": -0.15930226,
#             "4_C": -0.02271894,
#             "5_C": 0.00282455,
#             "6_C": -0.01005033,
#             "7_C": -0.17146641,
#             "8_C": -0.01012072,
#             "9_C": 0.00274209,
#             "10_H": 0.06333984,
#             "11_H": 0.06330708,
#             "12_H": 0.06080638,
#             "13_H": 0.03486435,
#             "14_H": 0.03481622,
#             "15_H": 0.01780582,
#             "16_H": 0.02503342,
#             "17_H": 0.02290911,
#             "18_H": 0.03821601,
#             "19_H": 0.07438067,
#             "20_H": 0.02294,
#             "21_H": 0.02499584
#         },
#         "dipole": {
#             "mag": 0.02717,
#             "xyz": [
#                 -0.007772,
#                 0.02023,
#                 0.016387
#             ]
#         },
#         "atomic_dipole": {
#             "1_C": [
#                 -0.005854,
#                 -0.337174,
#                 0.027077
#             ],
#             "2_C": [
#                 -0.027584,
#                 -0.280138,
#                 0.070387
#             ],
#             "3_C": [
#                 -0.180486,
#                 0.013239,
#                 0.383442
#             ],
#             "4_C": [
#                 -0.036815,
#                 0.440763,
#                 0.059882
#             ],
#             "5_C": [
#                 -0.391351,
#                 0.008953,
#                 -0.111385
#             ],
#             "6_C": [
#                 -0.19487,
#                 0.160704,
#                 -0.337007
#             ],
#             "7_C": [
#                 0.101325,
#                 -0.341206,
#                 -0.201243
#             ],
#             "8_C": [
#                 0.378382,
#                 0.171786,
#                 -0.067798
#             ],
#             "9_C": [
#                 0.335225,
#                 0.0235,
#                 0.230049
#             ],
#             "10_H": [
#                 -0.166445,
#                 -0.103108,
#                 0.030671
#             ],
#             "11_H": [
#                 0.085177,
#                 -0.097929,
#                 0.149762
#             ],
#             "12_H": [
#                 0.05644,
#                 -0.145939,
#                 -0.112641
#             ],
#             "13_H": [
#                 0.065426,
#                 0.011975,
#                 0.197682
#             ],
#             "14_H": [
#                 -0.194206,
#                 0.006834,
#                 0.075733
#             ],
#             "15_H": [
#                 -0.007754,
#                 0.201181,
#                 0.008029
#             ],
#             "16_H": [
#                 -0.200096,
#                 0.002252,
#                 -0.037929
#             ],
#             "17_H": [
#                 -0.056073,
#                 0.110169,
#                 -0.148818
#             ],
#             "18_H": [
#                 0.080902,
#                 -0.034566,
#                 -0.170807
#             ],
#             "19_H": [
#                 0.000669,
#                 -0.190742,
#                 0.006577
#             ],
#             "20_H": [
#                 0.146718,
#                 0.11413,
#                 -0.053602
#             ],
#             "21_H": [
#                 0.15679,
#                 0.009349,
#                 0.129648
#             ]
#         }
#     },
#     "adch": {
#         "charge": {
#             "1_C": -0.23708757,
#             "2_C": -0.0033669,
#             "3_C": -0.18489631,
#             "4_C": -0.10410266,
#             "5_C": -0.08838157,
#             "6_C": -0.12309978,
#             "7_C": -0.19647192,
#             "8_C": -0.1231553,
#             "9_C": -0.08835742,
#             "10_H": 0.08984652,
#             "11_H": 0.08985359,
#             "12_H": 0.08633073,
#             "13_H": 0.08434444,
#             "14_H": 0.08432431,
#             "15_H": 0.10269039,
#             "16_H": 0.09582766,
#             "17_H": 0.10837509,
#             "18_H": 0.11429268,
#             "19_H": 0.08879279,
#             "20_H": 0.10839898,
#             "21_H": 0.09584225
#         },
#         "dipole": {
#             "mag": 0.0265005,
#             "xyz": [
#                 -0.007934,
#                 0.019921,
#                 0.015572
#             ]
#         },
#         "atomic_dipole": {
#             "1_C": [
#                 -0.001804,
#                 -0.013351,
#                 0.004521
#             ],
#             "2_C": [
#                 -0.000468,
#                 0.088648,
#                 -0.002644
#             ],
#             "3_C": [
#                 0.017812,
#                 0.000843,
#                 -0.038026
#             ],
#             "4_C": [
#                 0.00682,
#                 -0.079722,
#                 -0.011108
#             ],
#             "5_C": [
#                 0.037006,
#                 0.001894,
#                 0.04765
#             ],
#             "6_C": [
#                 0.042591,
#                 -0.013562,
#                 0.020658
#             ],
#             "7_C": [
#                 -0.011738,
#                 0.023434,
#                 0.023987
#             ],
#             "8_C": [
#                 -0.042609,
#                 -0.01526,
#                 -0.019356
#             ],
#             "9_C": [
#                 -0.060461,
#                 -1.8e-05,
#                 0.00187
#             ],
#             "10_H": [
#                 0.129151,
#                 0.043657,
#                 -0.017539
#             ],
#             "11_H": [
#                 -0.069668,
#                 0.039531,
#                 -0.111685
#             ],
#             "12_H": [
#                 -0.047282,
#                 0.079525,
#                 0.096163
#             ],
#             "13_H": [
#                 -0.061861,
#                 -0.002406,
#                 -0.11603
#             ],
#             "14_H": [
#                 0.128819,
#                 0.001374,
#                 -0.026489
#             ],
#             "15_H": [
#                 -6.4e-05,
#                 -0.133176,
#                 0.005719
#             ],
#             "16_H": [
#                 0.133615,
#                 0.001274,
#                 0.019536
#             ],
#             "17_H": [
#                 0.036608,
#                 -0.09133,
#                 0.109879
#             ],
#             "18_H": [
#                 -0.063015,
#                 -0.001143,
#                 0.134204
#             ],
#             "19_H": [
#                 0.013228,
#                 0.129135,
#                 -0.033375
#             ],
#             "20_H": [
#                 -0.104966,
#                 -0.094077,
#                 0.04345
#             ],
#             "21_H": [
#                 -0.100319,
#                 -0.003366,
#                 -0.090324
#             ]
#         }
#     },
#     "cm5": {
#         "charge": {
#             "1_C": -0.22016635,
#             "2_C": 0.00321857,
#             "3_C": -0.15760149,
#             "4_C": -0.07625721,
#             "5_C": -0.07135147,
#             "6_C": -0.10306512,
#             "7_C": -0.16786942,
#             "8_C": -0.10307317,
#             "9_C": -0.07129889,
#             "10_H": 0.08024439,
#             "11_H": 0.08024894,
#             "12_H": 0.07944138,
#             "13_H": 0.07221768,
#             "14_H": 0.07220801,
#             "15_H": 0.07772825,
#             "16_H": 0.07922997,
#             "17_H": 0.0873196,
#             "18_H": 0.0879916,
#             "19_H": 0.08428124,
#             "20_H": 0.08734314,
#             "21_H": 0.07921034
#         },
#         "dipole": {
#             "mag": 0.064262,
#             "xyz": [
#                 0.010669,
#                 0.058017,
#                 -0.025491
#             ]
#         }
#     },
#     "hirshfeld": {
#         "charge": {
#             "1_C": -0.07640745,
#             "2_C": 0.0247918,
#             "3_C": -0.0578844,
#             "4_C": -0.01783364,
#             "5_C": -0.01589725,
#             "6_C": -0.04317737,
#             "7_C": -0.06438267,
#             "8_C": -0.04317925,
#             "9_C": -0.01585663,
#             "10_H": 0.02875515,
#             "11_H": 0.02876288,
#             "12_H": 0.02727606,
#             "13_H": 0.01780491,
#             "14_H": 0.01779972,
#             "15_H": 0.02301631,
#             "16_H": 0.02248256,
#             "17_H": 0.03037409,
#             "18_H": 0.0335247,
#             "19_H": 0.02716522,
#             "20_H": 0.03038922,
#             "21_H": 0.02247602
#         },
#         "dipole": {
#             "mag": 0.064262,
#             "xyz": [
#                 0.010669,
#                 0.058017,
#                 -0.025491
#             ]
#         }
#     }
# }

# %%
print("Bonding Data:")
print(json.dumps(bonds_data, indent=4))
# Out:
# Bonding Data:
# {
#     "fuzzy_bond": {
#         "1_C_to_2_C": 1.1320677,
#         "1_C_to_3_C": 0.06278666,
#         "1_C_to_10_H": 0.8948379,
#         "1_C_to_11_H": 0.89535529,
#         "1_C_to_12_H": 0.8896822,
#         "2_C_to_3_C": 0.98652356,
#         "2_C_to_4_C": 0.20796905,
#         "2_C_to_5_C": 0.93248368,
#         "2_C_to_6_C": 0.05300685,
#         "2_C_to_8_C": 0.05310545,
#         "2_C_to_9_C": 0.93262231,
#         "2_C_to_10_H": 0.05244607,
#         "2_C_to_11_H": 0.05241109,
#         "3_C_to_4_C": 1.03457564,
#         "3_C_to_5_C": 0.12533353,
#         "3_C_to_9_C": 0.12532515,
#         "3_C_to_13_H": 0.88278087,
#         "3_C_to_14_H": 0.88285522,
#         "4_C_to_5_C": 0.95453624,
#         "4_C_to_6_C": 0.07011789,
#         "4_C_to_8_C": 0.07014577,
#         "4_C_to_9_C": 0.95444353,
#         "4_C_to_15_H": 0.87644174,
#         "5_C_to_6_C": 1.04422103,
#         "5_C_to_7_C": 0.05837908,
#         "5_C_to_8_C": 0.07475189,
#         "5_C_to_9_C": 0.13645753,
#         "5_C_to_16_H": 0.86405913,
#         "6_C_to_7_C": 1.05782071,
#         "6_C_to_8_C": 0.98783445,
#         "6_C_to_9_C": 0.07468849,
#         "6_C_to_17_H": 0.87210593,
#         "7_C_to_8_C": 1.05772261,
#         "7_C_to_9_C": 0.05841822,
#         "7_C_to_18_H": 0.89230797,
#         "7_C_to_19_H": 0.86218392,
#         "8_C_to_9_C": 1.04433599,
#         "8_C_to_20_H": 0.8718512,
#         "9_C_to_21_H": 0.86246428
#     }
# }
