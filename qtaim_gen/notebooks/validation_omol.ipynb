# %%
import json
import os 
from qtaim_gen.source.core.io import convert_inp_to_xyz
from qtaim_gen.source.core.parse_qtaim import dft_inp_to_dict
from qtaim_gen.source.core.omol import parse_multiwfn 
from qtaim_gen.source.core.validation import validation_checks

root_a = "/home/santiagovargas/dev/qtaim_generator/data/omol_full_tests/transfer/MOR39_La3Ir3_Charge4_UHF4_swaplig_0_newlig_NCc1ccccc10_step4_4_5/"
root_base = "/home/santiagovargas/dev/qtaim_generator/data/omol_test_spin_skip/base_test/"
root_uks = "/home/santiagovargas/dev/qtaim_generator/data/omol_test_spin_skip/orca6_uks/"
print(os.listdir(root_a))
# Out:
# ['qtaim.json', 'orca.engrad', 'charge.json', 'props_convert.mfwn', 'orca.out', 'timings.json', 'orca.property.txt', 'orca.inp.orig', 'props_qtaim.mfwn', 'qtaim.txt', 'props_other.mfwn', 'orca.gbw', 'orca.inp', 'orca_stderr', 'convert.txt', 'convert.out', 'other.txt', 'convert.in', 'fuzzy_full.json', 'orca.tar.zst', 'orca.gbw.zstd0', 'other.json']

# %%
validation_checks(root_a)
# Out:
# inp_files: ['orca.inp']
# True

# %%
validation_checks(root_base, verbose=False)
# Out:
# inp_files: ['input.in']
# True

# %%
validation_checks(root_uks)
# Out:
# inp_files: ['orca.inp']
# True

# %%
from qtaim_gen.source.core.utils import check_folder_writing

# %%
check_folder_writing(root_a)
# Out:
# 426285.61367607117

# %%
check_folder_writing(root_base)
# Out:
# 257862.07006669044

# %%
check_folder_writing(root_uks)
# Out:
# 16.041794300079346

# %%
import glob, os

base_folder = "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol"

subdirs = [d for depth in range(1, 5)
           for d in glob.glob(os.path.join(base_folder, *["*"]*depth, ""))
           #if os.path.isdir(d)]
]


for subdir in subdirs:
    if not os.path.isdir(subdir):
        continue
    # if there is a file timings.json validate it, else dont
    timings_file = os.path.join(subdir, "timings.json")
    if not os.path.isfile(timings_file):
        #print(f"Skipping {subdir} as it does not contain timings.json")
        continue
    # validating the subdir
    print(f"Validating {subdir}")
    validation_checks(subdir, verbose=False)
# Out:
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/pdb_fragments_300K/5dxb_ABS02_state0_-1_1_ZINC000754129284_ligstate1_-1_1/
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/electrolytes_redox/2174_C8H18N+_3_shell_2014_-1_2/
# Missing required file: fuzzy_full.json
# Missing required file: other.json
# Missing required file: charge.json
# Missing required file: qtaim.json
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/orbnet_denali/orbnet_saltcomplex_32590_CHEMBL135226_Lithium_a8cab331536ca7ef1eeecdb795825feb19ee59d8d958375f1ee63687909d83b5_1713500_0_1/
# Missing required file: fuzzy_full.json
# Missing required file: charge.json
# Missing required file: qtaim.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 21
# ...

# %%
path_dir = "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/dna/3hx0_L6_S--_frame1_-1_1/"
validation_checks(path_dir, verbose=True)
# Out:
# Using input file "orca.inp" for validation.
# n_atoms: 35, spin: 1, charge: -1
# Timing json structure is valid.
# Fuzzy json structure is valid.
# ...
# False

# %%
path_dir = "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/dna/3hx0_L6_S--_frame1_-1_1/"
validation_checks(path_dir, verbose=True)
# Out:
# Using input file "orca.inp" for validation.
# n_atoms: 35, spin: 1, charge: -1
# Timing json structure is valid.
# Fuzzy json structure is valid.
# ...
# False

# %%
list_paths=[
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani1xbb/aniBB_004_7500_0_1/", 
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani1xbb/aniBB_034_12011_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani2x/ani2x_019_150620_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani2x/ani2x_019_78813_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/dna/3hx0_L6_S--_frame1_-1_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/electrolytes_redox/2174_C8H18N+_3_shell_2014_-1_2/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/geom_orca6/geom_107883809_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/geom_orca6/geom_114263269_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/geom_orca6/geom_131247952_1_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ml_elytes/elytes_md_eqv2_electro_512_C3H8O_3_group_133_shell_0_0_1_1341/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ml_mo/mo_md_eqv2_mo_4583_1_-1_3_318/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ml_protein_interface/protein_interface_md_eqv2_bio_1n20_ifaceA393_0_1_129/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/orbnet_denali/orbnet_saltcomplex_32590_CHEMBL135226_Lithium_a8cab331536ca7ef1eeecdb795825feb19ee59d8d958375f1ee63687909d83b5_1713500_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/pdb_fragments_300K/5dxb_ABS02_state0_-1_1_ZINC000754129284_ligstate1_-1_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/pdb_pockets_300K/5ybn_ABS02_state1_frame0_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/tm_react/MOR31_Pd4_Charge2_UHF4_swaplig_0_newlig_O1BOc2ccccc121_rev_step2_2_5/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/tm_react/ROST13_Eu2_Charge0_UHF7_swaplig_1_newlig_CO1_step29_0_8/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/trans1x/t1x_rxn4386_706_670_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/trans1x/t1x_rxn8618_434_419_0_1/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/omol/metal_organics/restart5to6/job_1741387354_9825660a5ad0/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/omol/metal_organics/restart5to6/job_1741405396_2a875134f09d/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/omol/metal_organics/restart5to6/job_1741417653_415fb21d3e88/",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/omol/metal_organics/restart5to6/job_1741442191_7d5b9058a84a/timings.json",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/omol/metal_organics/restart5to6/job_1741553883_9ac418ad9597/timings.json",
    "/home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/omol/metal_organics/restart5to6/job_1741629859_ad9314cf2f55/timings.json"
]

for path in list_paths:
    print(f"Validating {path}")
    validation_checks(path, verbose=False)
    #print(f"Validating {path} - DONE")  # IGNORE this line, it was used for debugging
# Out:
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani1xbb/aniBB_004_7500_0_1/
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani1xbb/aniBB_034_12011_0_1/
# Missing required file: fuzzy_full.json
# Missing required file: charge.json
# Missing required file: qtaim.json
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani2x/ani2x_019_150620_0_1/
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/ani2x/ani2x_019_78813_0_1/
# Missing required file: fuzzy_full.json
# Missing required file: other.json
# Missing required file: charge.json
# Missing required file: qtaim.json
# Validating /home/santiagovargas/dev/qtaim_generator/data/omol_full_test/omol_refs/gbws_omol/dna/3hx0_L6_S--_frame1_-1_1/
# ...

# %%
# open "out.txt", go thhrough each filepath and check that there is a 
# timings.json file in the path, if not, print the path
with open("out.txt", "r") as f:
    for line in f:
        path = line.strip()
        timings_file = os.path.join(path, "timings.json")
        if not os.path.isfile(timings_file):
            print(f"Missing timings.json in {path}")
        else:
            print(f"Found timings.json in {path}")
